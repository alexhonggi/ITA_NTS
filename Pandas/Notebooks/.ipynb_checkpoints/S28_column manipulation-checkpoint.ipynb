# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(np.arange(30).reshape(5, 6),\
     index=['A', 'B', 'C', 'D', 'E'],\
     columns=['a', 'b', 'c', 'd', 'e', 'f'])
df
# Out:
#     a   b   c   d   e   f
# A   0   1   2   3   4   5
# B   6   7   8   9  10  11
# C  12  13  14  15  16  17
# D  18  19  20  21  22  23
# E  24  25  26  27  28  29

# %% [markdown]
# ## 컬럼 조작
# ### 컬럼 추출

# %%
df['c']
# Out:
# A     2
# B     8
# C    14
# D    20
# E    26
# Name: c, dtype: int32

# %%
df[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-b5f2749c85df> in <module>
# ----> 1 df[2]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 2

# %% [markdown]
# - 복수개 컬럼 추출 → DataFrame 객체

# %%
df[['a','b','c']]
# Out:
#     a   b   c
# A   0   1   2
# B   6   7   8
# C  12  13  14
# D  18  19  20
# E  24  25  26

# %% [markdown]
# ### 컬럼 추가

# %% [markdown]
# - 단일 컬럼 추출 → Series 객체

# %%
df['x'] = np.arange(5)
df['x']
# Out:
# A    0
# B    1
# C    2
# D    3
# E    4
# Name: x, dtype: int32

# %%
df
# Out:
#     a   b   c   d   e   f  x
# A   0   1   2   3   4   5  0
# B   6   7   8   9  10  11  1
# C  12  13  14  15  16  17  2
# D  18  19  20  21  22  23  3
# E  24  25  26  27  28  29  4

# %% [markdown]
# ### Drop

# %%
df
# Out:
#     a   b   c   d   e   f  x
# A   0   1   2   3   4   5  0
# B   6   7   8   9  10  11  1
# C  12  13  14  15  16  17  2
# D  18  19  20  21  22  23  3
# E  24  25  26  27  28  29  4

# %% [markdown]
# - 열 삭제

# %%
df.drop(['x'], axis=1)
# Out:
#     a   b   c   d   e   f
# A   0   1   2   3   4   5
# B   6   7   8   9  10  11
# C  12  13  14  15  16  17
# D  18  19  20  21  22  23
# E  24  25  26  27  28  29

# %% [markdown]
# - 행 삭제

# %%
df.drop(['A'])
# Out:
#     a   b   c   d   e   f  x
# B   6   7   8   9  10  11  1
# C  12  13  14  15  16  17  2
# D  18  19  20  21  22  23  3
# E  24  25  26  27  28  29  4

# %% [markdown]
# ### 여러 열/행 삭제

# %%
df.drop(['a', 'b', 'c'], axis=1)
# Out:
#     d   e   f  x
# A   3   4   5  0
# B   9  10  11  1
# C  15  16  17  2
# D  21  22  23  3
# E  27  28  29  4

# %%
df
# Out:
#     a   b   c   d   e   f  x
# A   0   1   2   3   4   5  0
# B   6   7   8   9  10  11  1
# C  12  13  14  15  16  17  2
# D  18  19  20  21  22  23  3
# E  24  25  26  27  28  29  4

# %%
df.drop('x', axis=1, inplace=True)

# %%
df
# Out:
#     a   b   c   d   e   f
# A   0   1   2   3   4   5
# B   6   7   8   9  10  11
# C  12  13  14  15  16  17
# D  18  19  20  21  22  23
# E  24  25  26  27  28  29

# %% [markdown]
# ## 컬럼명 바꾸기
# - 『손에 잡히는 판다스, 문용준, chapter10』
# - rename(columns=[])

# %%
df = pd.read_csv('data_raw/nav_2018.csv', encoding='utf-8')
df
# Out:
#      Unnamed: 0               Date Start (ET)        Visitor/Neutral  PTS  \
# 0             0  Tue, Oct 17, 2017      8:01p         Boston Celtics   99
# 1             1  Tue, Oct 17, 2017     10:30p        Houston Rockets  122
# 2             2  Wed, Oct 18, 2017      7:30p        Milwaukee Bucks  108
# 3             3  Wed, Oct 18, 2017      8:30p          Atlanta Hawks  117
# 4             4  Wed, Oct 18, 2017      7:00p      Charlotte Hornets   90
# ..          ...                ...        ...                    ...  ...
# 99           99  Mon, Oct 30, 2017      9:00p       Dallas Mavericks   89
# 100         100  Tue, Oct 31, 2017      7:30p           Phoenix Suns  122
# 101         101  Tue, Oct 31, 2017      7:00p       Sacramento Kings   83
# 102         102  Tue, Oct 31, 2017     10:30p        Detroit Pistons   93
# 103         103  Tue, Oct 31, 2017      8:00p  Oklahoma City Thunder  110
#
#               Home/Neutral  PTS.1              .1  Attend.  Notes
# 0      Cleveland Cavaliers    102  Box Score  NaN    20562    NaN
# 1    Golden State Warriors    121  Box Score  NaN    19596    NaN
# 2           Boston Celtics    100  Box Score  NaN    18624    NaN
# 3         Dallas Mavericks    111  Box Score  NaN    19709    NaN
# 4          Detroit Pistons    102  Box Score  NaN    20491    NaN
# ..                     ...    ...        ...  ...      ...    ...
# 99               Utah Jazz    104  Box Score  NaN    16221    NaN
# 100          Brooklyn Nets    114  Box Score  NaN    12936    NaN
# 101         Indiana Pacers    101  Box Score  NaN    12245    NaN
# 102     Los Angeles Lakers    113  Box Score  NaN    17569    NaN
# 103        Milwaukee Bucks     91  Box Score  NaN    16713    NaN
#
# [104 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Start (ET)', 'Visitor/Neutral', 'PTS',
#        'Home/Neutral', 'PTS.1', ' ', ' .1', 'Attend.', 'Notes'],
#       dtype='object')

# %% [markdown]
# **컬럼명 변경**

# %%
column_names = {'Date': '경기일자', 'Start (ET)': 'start',
                'Visitor/Neutral': '방문팀', 
                'PTS': '방문팀점수', 'Home/Neutral': '홈팀',
                'PTS.1': '홈팀점수', '\xa0' : 'Box', 'Attend.':'관중수','\xa0.1': 'n_ot'}

# %%
df.rename(columns=column_names)
# Out:
#      Unnamed: 0               경기일자   start                    방문팀  방문팀점수  \
# 0             0  Tue, Oct 17, 2017   8:01p         Boston Celtics     99
# 1             1  Tue, Oct 17, 2017  10:30p        Houston Rockets    122
# 2             2  Wed, Oct 18, 2017   7:30p        Milwaukee Bucks    108
# 3             3  Wed, Oct 18, 2017   8:30p          Atlanta Hawks    117
# 4             4  Wed, Oct 18, 2017   7:00p      Charlotte Hornets     90
# ..          ...                ...     ...                    ...    ...
# 99           99  Mon, Oct 30, 2017   9:00p       Dallas Mavericks     89
# 100         100  Tue, Oct 31, 2017   7:30p           Phoenix Suns    122
# 101         101  Tue, Oct 31, 2017   7:00p       Sacramento Kings     83
# 102         102  Tue, Oct 31, 2017  10:30p        Detroit Pistons     93
# 103         103  Tue, Oct 31, 2017   8:00p  Oklahoma City Thunder    110
#
#                         홈팀  홈팀점수        Box n_ot    관중수  Notes
# 0      Cleveland Cavaliers   102  Box Score  NaN  20562    NaN
# 1    Golden State Warriors   121  Box Score  NaN  19596    NaN
# 2           Boston Celtics   100  Box Score  NaN  18624    NaN
# 3         Dallas Mavericks   111  Box Score  NaN  19709    NaN
# 4          Detroit Pistons   102  Box Score  NaN  20491    NaN
# ..                     ...   ...        ...  ...    ...    ...
# 99               Utah Jazz   104  Box Score  NaN  16221    NaN
# 100          Brooklyn Nets   114  Box Score  NaN  12936    NaN
# 101         Indiana Pacers   101  Box Score  NaN  12245    NaN
# 102     Los Angeles Lakers   113  Box Score  NaN  17569    NaN
# 103        Milwaukee Bucks    91  Box Score  NaN  16713    NaN
#
# [104 rows x 11 columns]
